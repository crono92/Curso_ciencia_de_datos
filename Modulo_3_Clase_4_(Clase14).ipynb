# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      -------------------------------------- 293.3/293.3 kB 9.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from seaborn) (1.24.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from seaborn) (2.0.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: cycler>=0.10 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from pandas>=0.25->seaborn) (2022.7)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from pandas>=0.25->seaborn) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\rodrigo\anaconda3\envs\pr_ne\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import warnings

warnings.filterwarnings("ignore")
sns.set()

# %%
np.random.seed(0)
x = np.random.randn(100)
ax = sns.distplot(x, hist = False, rug = True)

# %%
from scipy.stats import norm
ax = sns.distplot(x, fit = norm)

# %%
ax = sns.distplot(x, vertical = True, color = "y")

# %%
ax = sns.distplot(x, rug = True, kde_kws = {"color": "k", "lw": 3, "label": "KDE"},
hist_kws = {"histtype": "step", "lw":3, "alpha": 0.5,
"color": "g"})

# %%
tips = sns.load_dataset("tips")

# %%
ax = sns.jointplot(x = "total_bill", y = "tip", data =
tips)

# %%
tips = pd.read_csv("tips.csv")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
axis = sns.regplot(x = "total_bill", y = "tip", data
= tips, marker = "o")

# %%
ax = sns.barplot(x = "day", y = "total_bill", hue =
"sex", order = ["Sun", "Sat", "Thur", "Fri"], data =
tips, estimator = np.median, ci = 95, n_boot = 1000,
units = None, orient = None, color = None, palette =
"Set3", saturation = 0.75, errcolor = "c", errwidth =
1, capsize = 0.2, dodge = True, ax = None)

plt.legend(loc = "best")
plt.title("seaborn.barplot")
plt.show()

# %%
ax = sns.countplot(x = "day", hue = "smoker", data =
tips, palette = "Set3")

# %%
ax = sns.countplot(y = "day", hue = "smoker", data =
tips, facecolor = (0, 0, 0, 0,), linewidth = 2,
edgecolor = sns.color_palette("dark", 4))

# %%
ax = sns.boxplot(x = "day", y = "total_bill", hue =
"sex", data = tips, saturation = 1.2, width = 0.8,
fliersize = 5, palette = "Set2")

# %%
ax = sns.violinplot(x = tips["total_bill"])

# %%
ax = sns.violinplot(x='day', y='total_bill',
hue= "time", data = tips, palette=sns.hls_palette(8, l =
0.8, s = 0.5), split=True, scale = 'count', inner =
'quartile')

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic = sns.load_dataset("titanic")
titanic.sample(5)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class
# 560         0       3    male   NaN      0      0   7.7500        Q   Third  \
# 629         0       3    male   NaN      0      0   7.7333        Q   Third
# 149         0       2    male  42.0      0      0  13.0000        S  Second
# 15          1       2  female  55.0      0      0  16.0000        S  Second
# 240         0       3  female   NaN      1      0  14.4542        C   Third
#
#        who  adult_male deck  embark_town alive  alone
# 560    man        True  NaN   Queenstown    no   True
# 629    man        True  NaN   Queenstown    no   True
# 149    man        True  NaN  Southampton    no   True
# 15   woman       False  NaN  Southampton   yes   True
# 240  woman       False  NaN    Cherbourg    no  False

# %%
g = sns.FacetGrid(titanic, col = "pclass")
g.map_dataframe(sns.histplot, x = 'age')
